# %% [markdown]
# <a href="https://colab.research.google.com/github/Shirley-333/Text_Analysis_Final_Project/blob/main/Text_Analysis_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url="https://raw.githubusercontent.com/Pistonrings/Song-Lyrics-Analysis-2012-to-2022/refs/heads/master/billboard_2012_to_2022_top_100_song_lyrics.csv"

# %%
df = pd.read_csv(url)

# %%
print(df.columns.tolist())
# Out:
# ['Top100Year', 'SongTitle', 'Artist', 'LyricsStatus', 'Lyrics', 'ReleaseYear', 'Genre']

# %%
df.head(3)
# Out:
#    Top100Year                     SongTitle                          Artist  \
# 0        2012                 Call Me Maybe                Carly Rae Jepsen
# 1        2012                      Payphone  Maroon 5 Featuring Wiz Khalifa
# 2        2012  Somebody That I Used To Know          Gotye Featuring Kimbra
#
#    LyricsStatus                                             Lyrics  \
# 0          True  I threw a wish in the well\nDon't ask me, I'll...
# 1          True  I'm at a payphone trying to call home\nAll of ...
# 2          True  Now and then I think of when we were together\...
#
#   ReleaseYear          Genre
# 0        2012  R&B/Soul, Pop
# 1        2012  R&B/Soul, Pop
# 2        2011  R&B/Soul, Pop

# %%
df = df[df['LyricsStatus'] == True]

# %%
df = df.dropna(subset=['Genre', 'Lyrics'])

# %%
print(df['Genre'].nunique())
# Out:
# 219

# %%
print(len(df))
# Out:
# 962

# %%
df[['SongTitle', 'Artist', 'Genre', 'Lyrics']].head(5)
# Out:
#                       SongTitle                          Artist  \
# 0                 Call Me Maybe                Carly Rae Jepsen
# 1                      Payphone  Maroon 5 Featuring Wiz Khalifa
# 2  Somebody That I Used To Know          Gotye Featuring Kimbra
# 3                    Wide Awake                      Katy Perry
# 4           Where Have You Been                         Rihanna
#
#                                              Genre  \
# 0                                    R&B/Soul, Pop
# 1                                    R&B/Soul, Pop
# 2                                    R&B/Soul, Pop
# 3                            R&B/Soul, Pop, UK R&B
# 4  Dance-pop, R&B/Soul, Electro house, Pop, UK R&B
#
#                                               Lyrics
# 0  I threw a wish in the well\nDon't ask me, I'll...
# 1  I'm at a payphone trying to call home\nAll of ...
# 2  Now and then I think of when we were together\...
# 3  I'm wide awake\nI'm wide awake\nI'm wide awake...
# 4  I've been everywhere, man\nLooking for someone...

# %%
genre_counts = df['Genre'].value_counts().reset_index()
genre_counts.columns = ['Genre', 'Count']

# %%
print(genre_counts.head(10))
# Out:
#                                            Genre  Count
# 0                         Country music, Country    190
# 1                          R&B/Soul, Hip-Hop/Rap    118
# 2                                  R&B/Soul, Pop     51
# 3                         Alternative/Indie, Pop     37
# 4                      Bachata, Musica tropicale     26
# 5               Alternative/Indie, R&B/Soul, Pop     18
# 6                            Hip-Hop/Rap, UK Rap     17
# 7                          R&B/Soul, Pop, UK R&B     17
# 8                     R&B/Soul, Pop, Hip-Hop/Rap     12
# 9  Alternative/Indie, R&B/Soul, Pop, Hip-Hop/Rap     12

# %%
fig = px.bar(
    genre_counts.head(10).sort_values('Count', ascending=True),
    x='Count', y='Genre',
    orientation='h',
    title='Top 10 Genres by Song Count (2012–2022)',
    labels={'Genre': 'Music Genre', 'Count': 'Number of Songs'},
)
fig.update_traces(marker_color='pink')
fig.update_layout(
    plot_bgcolor='whitesmoke',
    paper_bgcolor='white',
    font=dict(size=14))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7100af0d-9ca7-4d4b-a8eb-7e9c86b9060c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7100af0d-9ca7-4d4b-a8eb-7e9c86b9060c")) {                    Plotly.newPlot(                        "7100af0d-9ca7-4d4b-a8eb-7e9c86b9060c",                        [{"alignmentgroup":"True","hovertemplate":"Number of Songs=%{x}\u003cbr\u003eMusic Genre=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"pink","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[12,12,17,17,18,26,37,51,118,190],"xaxis":"x","y":["Alternative\u002fIndie, R&B\u002fSoul, Pop, Hip-Hop\u002fRap","R&B\u002fSoul, Pop, Hip-Hop\u002fRap","Hip-Hop\u002fRap, UK Rap","R&B\u002fSoul, Pop, UK R&B","Alternative\u002fIndie, R&B\u002fSoul, Pop","Bachata, Musica tropicale","Alternative\u002fIndie, Pop","R&B\u002fSoul, Pop","R&B\u002fSoul, Hip-Hop\u002fRap","Country music, Country"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterp ...

# %%
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
from nltk.tokenize import RegexpTokenizer

# download required packages (same as in class)
needed = ["punkt_tab", "stopwords", "wordnet", "averaged_perceptron_tagger_eng"]
for pkg in needed:
    nltk.download(pkg, quiet=True)

# %%
def wordnet_pos(tag):
    """Map POS tag to WordNet POS tag format"""
    return {
        "J": wordnet.ADJ,
        "N": wordnet.NOUN,
        "V": wordnet.VERB,
        "R": wordnet.ADV
    }.get(tag[0], wordnet.NOUN)

# %%
def tokenize_norm(text):
    tok = RegexpTokenizer(r"[A-Za-z0-9]+")
    return [t.lower() for t in tok.tokenize(str(text))]

# %%
def remove_stopwords(tokens):
    stops = set(stopwords.words("english"))
    return [t for t in tokens if t not in stops]

# %%
def pos_lemmatize(tokens):
    tags = pos_tag(tokens)
    lem = WordNetLemmatizer()
    return [lem.lemmatize(t, wordnet_pos(tag)) for t, tag in tags]

# %%
def run_pipeline(text):
    tokens = tokenize_norm(text)
    tokens_nostop = remove_stopwords(tokens)
    clean = pos_lemmatize(tokens_nostop)
    return clean

# %%
sample_text = df['Lyrics'].iloc[0]
clean_tokens = run_pipeline(sample_text)

print("Original length:", len(sample_text.split()))
print("Cleaned token count:", len(clean_tokens))
print("Top 30 tokens:", clean_tokens[:30])
# Out:
# Original length: 416
# Cleaned token count: 168
# Top 30 tokens: ['threw', 'wish', 'well', 'ask', 'never', 'tell', 'look', 'fell', 'way', 'trade', 'soul', 'wish', 'penny', 'dim', 'kiss', 'look', 'way', 'stare', 'holdin', 'rip', 'jean', 'skin', 'showin', 'hot', 'night', 'wind', 'blowin', 'think', 'go', 'baby']

# %%
df['clean_tokens'] = df['Lyrics'].head(200).apply(run_pipeline)

# %%
import nltk
from nltk.probability import FreqDist

# Lexical diversity: unique words ÷ total words
def lexical_diversity(tokens):
    tokens = [t for t in tokens if isinstance(t, str)]
    return len(set(tokens)) / max(1, len(tokens))

# %%
df['lexical_diversity'] = df[df['clean_tokens'].notna()]['clean_tokens'].apply(lexical_diversity)

# %%
genre_diversity = (
    df.groupby('Genre', as_index=False)['lexical_diversity']
    .mean()
    .sort_values('lexical_diversity', ascending=False))

# %%
genre_diversity.head(10)
# Out:
#                                                  Genre  lexical_diversity
# 10   Alternative/Indie, Dance/Electronic, Pop, Hip-...           0.660633
# 49   Country music, House music, Folktronica, Dance...           0.600000
# 189  Rap rock, Electronic rock, Alternative/Indie, Pop           0.492172
# 3    Alternative rock, Pop rock, Indie rock, Altern...           0.480333
# 18   Alternative/Indie, R&B/Soul, Dance/Electronic,...           0.477366
# 153                                       Pop, Country           0.471342
# 163                   R&B/Soul, Alternative/Indie, Pop           0.470982
# 76       Electronic dance music, Electropop, Dance Pop           0.458515
# 46                              Country music, Country           0.455014
# 17   Alternative/Indie, R&B/Soul, Children's Music,...           0.448669

# %%
import plotly.express as px

fig = px.bar(
    genre_diversity,
    x='lexical_diversity',
    y='Genre',
    orientation='h',
    title='Average Lexical Diversity by Genre (2012–2022)',
    labels={'lexical_diversity': 'Average Lexical Diversity', 'Genre': 'Music Genre'})
fig.update_traces(marker_color='pink')

fig.update_layout(
    plot_bgcolor='whitesmoke',
    paper_bgcolor='white',
    font=dict(size=14))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f830db85-f326-4d20-9236-681e318169ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f830db85-f326-4d20-9236-681e318169ad")) {                    Plotly.newPlot(                        "f830db85-f326-4d20-9236-681e318169ad",                        [{"alignmentgroup":"True","hovertemplate":"Average Lexical Diversity=%{x}\u003cbr\u003eMusic Genre=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"pink","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.6606334841628959,0.6,0.49217229362324577,0.4803334244324805,0.4773662551440329,0.47134241558965834,0.47098159509202453,0.4585152838427948,0.4550144058477046,0.44866920152091255,0.4416640018070613,0.43190661478599224,0.42754446037201915,0.4270833333333333,0.4258903278025091,0.41935483870967744,0.4166120576671035,0.41304347826086957,0.4124338624338625,0.40726759704110427,0.39975236031574063,0.39490445859872614,0.39244186046511625,0.3863893210641545,0.38596491228070173,0.3748961362692148,0.3715819222607624,0.3697478991596639,0.3687150837988827,0.36677775487952646,0.36666666666666664,0.36180904522613067,0.36097004847004843,0.36057787700019234,0.3562149859943977,0.34654539559703085,0.33544303797468356,0.32882882882882886,0.3170731707317073,0.3146853146853147,0.3126099706744868,0.31239550991163123,0.30097087378640774,0.2976884915226517,0.2695035460992908,0.2549800796812749,0.25,0.2356020942408377,0.2346368715083799,0.23383084577114427,0.22945205479452055,0.19339622641509435,0.174496644295302,0.13230769230769232,0.13043478260869565,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"xaxis":"x","y":["Alternative\u002fIndie, Dance\u002fElectronic, Pop, Hip-Hop\u002fRap","Country music, House music, Folktronica, Dance\u002fElectronic","Rap rock, Electronic rock, Alternative\u002fIndie, Pop","Alternative rock, Pop rock, Indie rock, Alternative\u002fIndie, Electropop, Children's Music, Pop","Alternative\u002fIndie, R&B\u002fSoul, Dance\u002fElectronic, Pop","Pop, Country","R&B\u002fSoul, Alternative\u002fIndie, Pop","Electronic dance music, Electropop, Dance Pop","Country music, Country","Alternative\u002fIndie, R&B\u002fSoul, Children's Music, Dance\u002fElectronic, Pop, Hip-Hop\u002fRap","Hip house, Hip-Hop\u002fRap","Alternative\u002fIndie, R&B\u002fSoul, Dance\u002fElectronic, Pop, UK R&B, Hip-Hop\u002fRap, French Urban Pop\u002fR&B","R&B\u002fSoul, Hip-Hop\u002fRap","Dubstep, Alternative\u002fIndie, R&B\u002fSoul, Dance\u002fElectronic, Pop","Alternative\u002fIndie, Pop, Seasonal","Alternative\u002fIndie, R&B\u002fSoul, Pop, UK R&B","R&B\u002fSoul, Dance\u002fElectronic, Pop, Hip-Hop\u002fRap, French Urban Pop\u002fR&B","Electronic dance music, House","Pop music, R&B\u002fSoul, Pop, Reggae","Electronic dance music, R&B\u002fSoul, Pop, UK R&B, Hip-Hop\u002fRap, French Urban Pop\u002fR&B","Alternative\u002fIndie, R&B\u002fSoul, Me ...

# %%
fig = px.bar(
    genre_diversity.head(10).sort_values('lexical_diversity', ascending=True),
    x='lexical_diversity',
    y='Genre',
    orientation='h',
    title='Top 10 Genres by Lexical Diversity (2012–2022)',
    labels={'lexical_diversity': 'Average Lexical Diversity', 'Genre': 'Music Genre'})

fig.update_traces(marker_color='pink')
fig.update_layout(
    plot_bgcolor='whitesmoke',
    paper_bgcolor='white',
    font=dict(size=14))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3af3ec0e-68a5-40bd-96b5-b7dfc9452633" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3af3ec0e-68a5-40bd-96b5-b7dfc9452633")) {                    Plotly.newPlot(                        "3af3ec0e-68a5-40bd-96b5-b7dfc9452633",                        [{"alignmentgroup":"True","hovertemplate":"Average Lexical Diversity=%{x}\u003cbr\u003eMusic Genre=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"pink","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[0.44866920152091255,0.4550144058477046,0.4585152838427948,0.47098159509202453,0.47134241558965834,0.4773662551440329,0.4803334244324805,0.49217229362324577,0.6,0.6606334841628959],"xaxis":"x","y":["Alternative\u002fIndie, R&B\u002fSoul, Children's Music, Dance\u002fElectronic, Pop, Hip-Hop\u002fRap","Country music, Country","Electronic dance music, Electropop, Dance Pop","R&B\u002fSoul, Alternative\u002fIndie, Pop","Pop, Country","Alternative\u002fIndie, R&B\u002fSoul, Dance\u002fElectronic, Pop","Alternative rock, Pop rock, Indie rock, Alternative\u002fIndie, Electropop, Children's Music, Pop","Rap rock, Electronic rock, Alternative\u002fIndie, Pop","Country music, House music, Folktronica, Dance\u002fElectronic","Alternative\u002fIndie, Dance\u002fElectronic, Pop, Hip-Hop\u002fRap"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555555 ...

# %%
from nltk.probability import FreqDist

# %%
subset = df[df['Genre'].str.contains('Pop', case=False, na=False)]

# %%
from nltk.probability import FreqDist
import pandas as pd
import plotly.express as px

subset = df[df['Genre'].str.contains('Pop', case=False, na=False)]
print("Pop songs found:", len(subset))

all_words = [word for tokens in subset['clean_lyrics'] for word in tokens]
fdist = FreqDist(all_words)
top_words = fdist.most_common(20)
word_df = pd.DataFrame(top_words, columns=['Word', 'Count'])

fig = px.bar(
    word_df,
    x='Count',
    y='Word',
    orientation='h',
    title='Top 20 Words in Pop Lyrics',
    labels={'Count': 'Frequency', 'Word': 'Word'})

fig.update_traces(marker_color='#ff99cc')
fig.update_layout(
    plot_bgcolor='whitesmoke',
    paper_bgcolor='white',
    font=dict(size=14))
fig.show()
# Out:
# Pop songs found: 494
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="24c15d72-e01e-4d59-bdcd-250d48e85496" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24c15d72-e01e-4d59-bdcd-250d48e85496")) {                    Plotly.newPlot(                        "24c15d72-e01e-4d59-bdcd-250d48e85496",                        [{"alignmentgroup":"True","hovertemplate":"Frequency=%{x}\u003cbr\u003eWord=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#ff99cc","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[2379,2040,1871,1752,1600,1402,1244,1057,980,896,843,816,800,771,732,714,708,705,677,655],"xaxis":"x","y":["oh","get","yeah","like","know","love","go","ooh","baby","say","la","make","let","come","cause","want","need","take","wanna","one"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6 ...

# %%
# Code structure refined with the help of ChatGPT
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon', quiet=True)

sia = SentimentIntensityAnalyzer()

# Create sentiment column (analyzing each lyric)
df['sentiment'] = df['Lyrics'].apply(lambda x: sia.polarity_scores(str(x))['compound'])

# %%
subset = df[df['Genre'].str.contains('Pop', case=False, na=False)]

subset['Main_Genre'] = subset['Genre'].apply(
    lambda x: 'Pop' if 'Pop' in str(x) and 'Hip-Hop' not in str(x)
    else 'Hip-Hop/Rap' if 'Hip-Hop' in str(x) else 'Other')
genre_sentiment_compare =(
    subset.groupby('Main_Genre', as_index=False)['sentiment']
    .mean()
    .sort_values('sentiment', ascending=False))

import plotly.express as px

fig = px.bar(
    genre_sentiment_compare,
    x='Main_Genre',
    y='sentiment',
    title='Average Sentiment: Pop vs Hip-Hop/Rap (2012–2022)',
    labels={'sentiment': 'Average Sentiment Score', 'Main_Genre': 'Music Genre'}
)

fig.update_traces(marker_color='pink')
fig.update_layout(
    plot_bgcolor='white',
    paper_bgcolor='white',
    font=dict(size=15),
    xaxis=dict(tickangle=0),
    yaxis=dict(range=[-1, 1])
)
fig.show()
# Out:
# /tmp/ipython-input-2495916020.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c70b9119-ce0b-47cb-9c63-bdc5b3d09f64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c70b9119-ce0b-47cb-9c63-bdc5b3d09f64")) {                    Plotly.newPlot(                        "c70b9119-ce0b-47cb-9c63-bdc5b3d09f64",                        [{"alignmentgroup":"True","hovertemplate":"Music Genre=%{x}\u003cbr\u003eAverage Sentiment Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"pink","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Pop","Hip-Hop\u002fRap","Other"],"xaxis":"x","y":[0.313251329787234,0.15533663366336634,0.13598461538461537],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type" ...
